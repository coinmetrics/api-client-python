# %% [markdown]
# # Coin Metrics - Market Data Feed
# ## > OPTION CHAIN EXAMPLE

# %% [markdown]
# ### Notebook configuration:

# %%
import os
from os import environ
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import logging
from datetime import date, datetime, timedelta
from coinmetrics.api_client import CoinMetricsClient
import json
import logging
from pytz import timezone as timezone_conv
from datetime import timezone as timezone_info
import matplotlib.ticker as mticker
from matplotlib.ticker import ScalarFormatter
import matplotlib.pyplot as plt
# %matplotlib inline

from pathlib import Path  

sns.set_theme()
sns.set(rc={'figure.figsize':(12,8)})

# %%
logging.basicConfig(
    format='%(asctime)s %(levelname)-8s %(message)s',
    level=logging.INFO,
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
# We recommend privately storing your API key in your local environment.
try:
    api_key = environ["CM_API_KEY"]
    logging.info("Using API key found in environment")
except KeyError:
    api_key = ""
    logging.info("API key not found. Using community client")

client = CoinMetricsClient(api_key)
# Out:
# 2022-03-30 11:19:54 INFO     API key not found. Using community client

# %% [markdown]
# ## Pulling options quotes:

# %%
deribit_quotes = client.get_market_quotes(
    markets='deribit-*-option',
    limit_per_market=1
).to_dataframe()

# %%
deribit_quotes
# Out:
#                                  market                      time  \
# 0    deribit-BTC-15APR22-25000-C-option 2022-03-30 15:19:00+00:00
# 1    deribit-BTC-15APR22-25000-P-option 2022-03-30 15:19:00+00:00
# 2    deribit-BTC-15APR22-30000-C-option 2022-03-30 15:19:00+00:00
# 3    deribit-BTC-15APR22-30000-P-option 2022-03-30 15:19:00+00:00
# 4    deribit-BTC-15APR22-34000-C-option 2022-03-30 15:19:00+00:00
# ..                                  ...                       ...
# 931    deribit-ETH-8APR22-4000-P-option 2022-03-30 15:19:00+00:00
# 932    deribit-ETH-8APR22-4200-C-option 2022-03-30 15:19:00+00:00
# 933    deribit-ETH-8APR22-4200-P-option 2022-03-30 15:19:00+00:00
# 934    deribit-ETH-8APR22-4500-C-option 2022-03-30 15:19:00+00:00
# 935    deribit-ETH-8APR22-4500-P-option 2022-03-30 15:19:00+00:00
#
#         coin_metrics_id  ask_price  ask_size  bid_price  bid_size
# 0    1648653540000000-0     0.5085      22.1      0.439      21.2
# 1    1648653540000000-0     0.0005      22.5        0.0       0.0
# 2    1648653540000000-0      0.443       0.3      0.303       8.0
# 3    1648653540000000-0     0.0005       0.5        0.0       0.0
# 4    1648653540000000-0      0.359       0.3      0.219      22.8
# ..                  ...        ...       ...        ...       ...
# 931  1648653540000000-0       0.59       5.0        0.0       0.0
# 932  1648653540000000-0      0.001     100.0     0.0005     914.0
# 933  1648653540000000-0     0.6485       5.0        0.0       0.0
# 934  1648653540000000-0     0.0005     232.0        0.0       0.0
# 935  1648653540000000-0      0.737       5.0     0.0365       5.0
#
# [936 rows x 7 columns]

# %% [markdown]
# ### Select an asset ticker:

# %%
asset='BTC'

# %% [markdown]
# ### Extract the asset ticker, expiry date, and the option type (call/put) from contract names:

# %%
split = deribit_quotes["market"].str.split("-")[0:]

# %%
split
# Out:
# 0      [deribit, BTC, 15APR22, 25000, C, option]
# 1      [deribit, BTC, 15APR22, 25000, P, option]
# 2      [deribit, BTC, 15APR22, 30000, C, option]
# 3      [deribit, BTC, 15APR22, 30000, P, option]
# 4      [deribit, BTC, 15APR22, 34000, C, option]
#                          ...
# 931      [deribit, ETH, 8APR22, 4000, P, option]
# 932      [deribit, ETH, 8APR22, 4200, C, option]
# 933      [deribit, ETH, 8APR22, 4200, P, option]
# 934      [deribit, ETH, 8APR22, 4500, C, option]
# 935      [deribit, ETH, 8APR22, 4500, P, option]
# Name: market, Length: 936, dtype: object

# %%
split_expiry = pd.DataFrame(datetime.strptime(i[2],'%d%b%y').strftime('%Y-%m-%d') for i in split)

# %%
split_asset = pd.DataFrame([i[1] for i in split])
split_strike = pd.DataFrame([i[3] for i in split])
split_side = pd.DataFrame([i[4] for i in split])

# %% [markdown]
# ### Remove the 'C-Option' and 'P-Option' suffixes to isolate expiration date and strike price:

# %%
split_market = pd.DataFrame((i[0:4] for i in split))

split_market['market'] = (
    split_market[0].astype(str) + 
    '-' + split_market[1].astype(str) + 
    '-' + split_market[2].astype(str) + 
    '-' + split_market[3].astype(str) )

# %%
split_market['market']
# Out:
# 0      deribit-BTC-15APR22-25000
# 1      deribit-BTC-15APR22-25000
# 2      deribit-BTC-15APR22-30000
# 3      deribit-BTC-15APR22-30000
# 4      deribit-BTC-15APR22-34000
#                  ...
# 931      deribit-ETH-8APR22-4000
# 932      deribit-ETH-8APR22-4200
# 933      deribit-ETH-8APR22-4200
# 934      deribit-ETH-8APR22-4500
# 935      deribit-ETH-8APR22-4500
# Name: market, Length: 936, dtype: object

# %% [markdown]
# ### Create new columns with categorical variables:

# %%
deribit_quotes['BTC'] = split_asset[0].isin([asset])

# %%
deribit_quotes['Call'] = split_side[0].isin(['C'])
deribit_quotes['Put'] = split_side[0].isin(['P'])
deribit_quotes['market'] = split_market['market']
deribit_quotes['strike'] = split_strike[:].astype(int)
deribit_quotes['expiry'] = split_expiry[:]

# %%
deribit_quotes
# Out:
#                         market                      time     coin_metrics_id  \
# 0    deribit-BTC-15APR22-25000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 1    deribit-BTC-15APR22-25000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 2    deribit-BTC-15APR22-30000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 3    deribit-BTC-15APR22-30000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 4    deribit-BTC-15APR22-34000 2022-03-30 15:19:00+00:00  1648653540000000-0
# ..                         ...                       ...                 ...
# 931    deribit-ETH-8APR22-4000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 932    deribit-ETH-8APR22-4200 2022-03-30 15:19:00+00:00  1648653540000000-0
# 933    deribit-ETH-8APR22-4200 2022-03-30 15:19:00+00:00  1648653540000000-0
# 934    deribit-ETH-8APR22-4500 2022-03-30 15:19:00+00:00  1648653540000000-0
# 935    deribit-ETH-8APR22-4500 2022-03-30 15:19:00+00:00  1648653540000000-0
#
#      ask_price  ask_size  bid_price  bid_size    BTC   Call    Put  strike  \
# 0       0.5085      22.1      0.439      21.2   True   True  False   25000
# 1       0.0005      22.5        0.0       0.0   True  False   True   25000
# 2        0.443       0.3      0.303       8.0   True   True  False   30000
# 3       0.0005       0.5        0.0       0.0   True  False   True   30000
# 4        0.359       0.3      0.219      22.8   True   True  False   34000
# ..         ...       ...        ...       ...    ...    ...    ...     ...
# 931       0.59       5.0        0.0       0.0  False  False   True    4000
# 932      0.001     100.0     0.0005     914.0  False   True  False    4200
# 933     0.6485       5.0        0.0       0.0  False  False   True    4200
# 934     0.0005     232.0        0.0       0.0  False   True  False    4500
# 935      0.737       5.0     0.0365       5.0  False  False   True    4500
#
#          expiry
# 0    2022-04-15
# 1    2022-04-15
# 2    2022-04-15
# 3    2022-04-15
# 4    2022-04-15
# ..          ...
# 931  2022-04-08
# 932  2022-04-08
# 933  2022-04-08
# 934  2022-04-08
# 935  2022-04-08
#
# [936 rows x 12 columns]

# %% [markdown]
# ###  Isolate Bitcoin markets:

# %%
btc_quotes = deribit_quotes.loc[deribit_quotes['BTC'] == True]

# %% [markdown]
# ### Sort by expiry and strike:

# %%
btc_quotes = btc_quotes.sort_values(by=["expiry","strike"],ascending=[True, True])

# %%
btc_quotes
# Out:
#                          market                      time     coin_metrics_id  \
# 270   deribit-BTC-30MAR22-38000 2022-03-30 08:00:00+00:00  1648627200000000-0
# 271   deribit-BTC-30MAR22-38000 2022-03-30 08:00:00+00:00  1648627200000000-0
# 272   deribit-BTC-30MAR22-40000 2022-03-30 08:00:00+00:00  1648627200000000-0
# 273   deribit-BTC-30MAR22-40000 2022-03-30 08:00:00+00:00  1648627200000000-0
# 274   deribit-BTC-30MAR22-41000 2022-03-30 08:00:00+00:00  1648627200000000-0
# ..                          ...                       ...                 ...
# 387  deribit-BTC-31MAR23-200000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 388  deribit-BTC-31MAR23-250000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 389  deribit-BTC-31MAR23-250000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 392  deribit-BTC-31MAR23-300000 2022-03-30 15:19:00+00:00  1648653540000000-0
# 393  deribit-BTC-31MAR23-300000 2022-03-30 15:19:00+00:00  1648653540000000-0
#
#      ask_price  ask_size  bid_price  bid_size   BTC   Call    Put  strike  \
# 270        0.0       0.0        0.0       0.0  True   True  False   38000
# 271        0.0       0.0        0.0       0.0  True  False   True   38000
# 272        0.0       0.0        0.0       0.0  True   True  False   40000
# 273        0.0       0.0        0.0       0.0  True  False   True   40000
# 274        0.0       0.0        0.0       0.0  True   True  False   41000
# ..         ...       ...        ...       ...   ...    ...    ...     ...
# 387        0.0       0.0        0.0       0.0  True  False   True  200000
# 388      0.009      19.3     0.0065       9.7  True   True  False  250000
# 389        0.0       0.0        0.0       0.0  True  False   True  250000
# 392      0.005       0.2      0.003      11.8  True   True  False  300000
# 393        0.0       0.0        0.0       0.0  True  False   True  300000
#
#          expiry
# 270  2022-03-30
# 271  2022-03-30
# 272  2022-03-30
# 273  2022-03-30
# 274  2022-03-30
# ..          ...
# 387  2023-03-31
# 388  2023-03-31
# 389  2023-03-31
# 392  2023-03-31
# 393  2023-03-31
#
# [454 rows x 12 columns]

# %% [markdown]
# ### Drop unnecessary columns:

# %%
btc_quotes = btc_quotes.drop(columns=['coin_metrics_id', 'time'])

# %% [markdown]
# ### Create separate dataframes for Calls and Puts:

# %%
btc_calls = btc_quotes.loc[btc_quotes['Call'] == True]
btc_puts = btc_quotes.loc[btc_quotes['Put'] == True]

# %% [markdown]
# ### Reformat Calls dataframe and drop duplicate markets:

# %%
btc_calls = btc_calls.rename(columns={"ask_price": "Call - Ask Price", 
                                      "ask_size": "Call - Ask Size", 
                                      "bid_price": "Call - Bid Price", 
                                      "bid_size": "Call - Bid Size", }).drop(columns=['BTC','Call','Put','expiry','strike'])
btc_calls = btc_calls[~btc_calls.market.duplicated(keep='first')]
btc_calls
# Out:
#                          market  Call - Ask Price  Call - Ask Size  \
# 270   deribit-BTC-30MAR22-38000               0.0              0.0
# 272   deribit-BTC-30MAR22-40000               0.0              0.0
# 274   deribit-BTC-30MAR22-41000               0.0              0.0
# 276   deribit-BTC-30MAR22-42000               0.0              0.0
# 278   deribit-BTC-30MAR22-43000               0.0              0.0
# ..                          ...               ...              ...
# 380  deribit-BTC-31MAR23-140000            0.0335             31.0
# 382  deribit-BTC-31MAR23-150000             0.028              9.5
# 386  deribit-BTC-31MAR23-200000            0.0145             23.2
# 388  deribit-BTC-31MAR23-250000             0.009             19.3
# 392  deribit-BTC-31MAR23-300000             0.005              0.2
#
#      Call - Bid Price  Call - Bid Size
# 270               0.0              0.0
# 272               0.0              0.0
# 274               0.0              0.0
# 276               0.0              0.0
# 278               0.0              0.0
# ..                ...              ...
# 380             0.028             18.8
# 382            0.0255              1.0
# 386            0.0125              5.0
# 388            0.0065              9.7
# 392             0.003             11.8
#
# [227 rows x 5 columns]

# %% [markdown]
# ### Reformat Puts dataframe and drop duplicate markets:

# %%
btc_puts = btc_puts.rename(columns={"ask_price": "Put - Ask Price", 
                                    "ask_size": "Put - Ask Size", 
                                    "bid_price": "Put - Bid Price", 
                                    "bid_size": "Put - Bid Size", }).drop(columns=['BTC','Call','Put','expiry','strike'])
btc_puts = btc_puts[~btc_puts.market.duplicated(keep='last')]
btc_puts
# Out:
#                          market  Put - Ask Price  Put - Ask Size  \
# 271   deribit-BTC-30MAR22-38000              0.0             0.0
# 273   deribit-BTC-30MAR22-40000              0.0             0.0
# 275   deribit-BTC-30MAR22-41000              0.0             0.0
# 277   deribit-BTC-30MAR22-42000              0.0             0.0
# 279   deribit-BTC-30MAR22-43000              0.0             0.0
# ..                          ...              ...             ...
# 381  deribit-BTC-31MAR23-140000              0.0             0.0
# 383  deribit-BTC-31MAR23-150000              0.0             0.0
# 387  deribit-BTC-31MAR23-200000              0.0             0.0
# 389  deribit-BTC-31MAR23-250000              0.0             0.0
# 393  deribit-BTC-31MAR23-300000              0.0             0.0
#
#      Put - Bid Price  Put - Bid Size
# 271              0.0             0.0
# 273              0.0             0.0
# 275              0.0             0.0
# 277              0.0             0.0
# 279              0.0             0.0
# ..               ...             ...
# 381              0.0             0.0
# 383              0.0             0.0
# 387              0.0             0.0
# 389              0.0             0.0
# 393              0.0             0.0
#
# [227 rows x 5 columns]

# %% [markdown]
# ### Merge Calls and Puts into unified Option Chain:

# %%
option_chain = pd.merge(btc_calls,btc_puts,on='market',validate='m:1')
option_chain = option_chain.set_index('market')
option_chain
# Out:
#                             Call - Ask Price  Call - Ask Size  \
# market
# deribit-BTC-30MAR22-38000                0.0              0.0
# deribit-BTC-30MAR22-40000                0.0              0.0
# deribit-BTC-30MAR22-41000                0.0              0.0
# deribit-BTC-30MAR22-42000                0.0              0.0
# deribit-BTC-30MAR22-43000                0.0              0.0
# ...                                      ...              ...
# deribit-BTC-31MAR23-140000            0.0335             31.0
# deribit-BTC-31MAR23-150000             0.028              9.5
# deribit-BTC-31MAR23-200000            0.0145             23.2
# deribit-BTC-31MAR23-250000             0.009             19.3
# deribit-BTC-31MAR23-300000             0.005              0.2
#
#                             Call - Bid Price  Call - Bid Size  \
# market
# deribit-BTC-30MAR22-38000                0.0              0.0
# deribit-BTC-30MAR22-40000                0.0              0.0
# deribit-BTC-30MAR22-41000                0.0              0.0
# deribit-BTC-30MAR22-42000                0.0              0.0
# deribit-BTC-30MAR22-43000                0.0              0.0
# ...                                      ...              ...
# deribit-BTC-31MAR23-140000             0.028             18.8
# deribit-BTC-31MAR23-150000            0.0255              1.0
# deribit-BTC-31MAR23-200000            0.0125              5.0
# deribit-BTC-31MAR23-250000            0.0065              9.7
# deribit-BTC-31MAR23-300000             0.003             11.8
#
#                             Put - Ask Price  Put - Ask Size  Put - Bid Price  \
# market
# deribit-BTC-30MAR22-38000               0.0             0.0              0.0
# deribit-BTC-30MAR22-40000               0.0             0.0              0.0
# deribit-BTC-30MAR22-41000               0.0             0.0              0.0
# deribit-BTC-30MAR22-42000               0.0             0.0              0.0
# deribit-BTC-30MAR22-43000               0.0             0.0              0.0
# ...                                     ...             ...              ...
# deribit-BTC-31MAR23-140000              0.0             0.0              0.0
# deribit-BTC-31MAR23-150000              0.0             0.0              0.0
# deribit-BTC-31MAR23-200000              0.0             0.0              0.0
# deribit-BTC-31MAR23-250000              0.0             0.0              0.0
# deribit-BTC-31MAR23-300000              0.0             0.0              0.0
#
#                             Put - Bid Size
# market
# deribit-BTC-30MAR22-38000              0.0
# deribit-BTC-30MAR22-40000              0.0
# deribit-BTC-30MAR22-41000              0.0
# deribit-BTC-30MAR22-42000              0.0
# deribit-BTC-30MAR22-43000              0.0
# ...                                    ...
# deribit-BTC-31MAR23-140000             0.0
# deribit-BTC-31MAR23-150000             0.0
# deribit-BTC-31MAR23-200000             0.0
# deribit-BTC-31MAR23-250000             0.0
# deribit-BTC-31MAR23-300000             0.0
#
# [227 rows x 8 columns]

# %% [markdown]
# ### Export to CSV:

# %%
filepath = Path('./' + asset + '-option-chain.csv')  
option_chain.to_csv(filepath)
